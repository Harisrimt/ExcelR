# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler
import warnings

# %%
df = pd.read_csv("ToyotaCorolla.csv", encoding = 'latin')
df.head(2)
# Out:
#    Id                                          Model  Price  Age_08_04  \
# 0   1  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 0                1               1      0          0            0
# 1                0               1      0          0            0
#
#    Backseat_Divider  Metallic_Rim  Radio_cassette  Tow_Bar
# 0                 1             0               0        0
# 1                 1             0               0        0
#
# [2 rows x 38 columns]

# %%
df.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'Model',
#  'Price',
#  'Age_08_04',
#  'Mfg_Month',
#  'Mfg_Year',
#  'KM',
#  'Fuel_Type',
#  'HP',
#  'Met_Color',
#  'Color',
#  'Automatic',
#  'cc',
#  'Doors',
#  'Cylinders',
#  'Gears',
#  'Quarterly_Tax',
#  'Weight',
#  'Mfr_Guarantee',
#  'BOVAG_Guarantee',
#  'Guarantee_Period',
#  'ABS',
#  'Airbag_1',
#  'Airbag_2',
#  'Airco',
#  'Automatic_airco',
#  'Boardcomputer',
#  'CD_Player',
#  'Central_Lock',
#  'Powered_Windows',
#  'Power_Steering',
#  'Radio',
#  'Mistlamps',
#  'Sport_Model',
#  'Backseat_Divider',
#  'Metallic_Rim',
#  'Radio_cassette',
#  'Tow_Bar']

# %%
df1 = df.copy()
df1 = df1.drop(["Id", 'Model', 'Mfg_Month', 'Mfg_Year', 'Fuel_Type', 'Met_Color', 'Color', 'Automatic',
                'Cylinders', 'Mfr_Guarantee', 'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1',
                'Airbag_2', 'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
                'Powered_Windows', 'Power_Steering', 'Radio','Mistlamps', 'Sport_Model', 'Backseat_Divider',
                'Metallic_Rim', 'Radio_cassette', 'Tow_Bar'], axis = 1)
df1.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
plt.figure(figsize = (10,4))
warnings.filterwarnings("ignore")

plt.subplot(3,3,1)
sns.distplot(df1["Price"])

plt.subplot(3,3,2)
sns.distplot(df1["Age_08_04"])

plt.subplot(3,3,3)
sns.distplot(df1["KM"])

plt.subplot(3,3,4)
sns.distplot(df1["HP"])

plt.subplot(3,3,5)
sns.distplot(df1["cc"])

plt.subplot(3,3,6)
sns.distplot(df1["Price"])

plt.subplot(3,3,7)
sns.distplot(df1["Doors"])

plt.subplot(3,3,8)
sns.distplot(df1["Gears"])

plt.subplot(3,3,9)
sns.distplot(df1["Quarterly_Tax"])
# Out:
# <Axes: xlabel='Quarterly_Tax', ylabel='Density'>

# %%
y = df1["Price"]
x = df1.drop(["Price"], axis = 1)

# %%
sns.heatmap(x.corr(), annot = True)
# Out:
# <Axes: >

# %%
x1 = sm.add_constant(x)
model = sm.OLS(y,x1).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Mon, 07 Aug 2023   Prob (F-statistic):               0.00
# Time:                        13:47:24   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
x_const = sm.add_constant(x1)
y_pred = model.predict(x_const)
r2 = r2_score(y,y_pred)
r2
# Out:
# 0.8637627463428191

# %%
df1.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %% [markdown]
# #### Using MinMax Scaler to see if the results have any change

# %%
scaler = MinMaxScaler()
x2 = scaler.fit_transform(x)
x2 = pd.DataFrame(x2, columns = x.columns.to_list())
x2 = sm.add_constant(x2)
x2.head()
# Out:
#    const  Age_08_04        KM        HP        cc     Doors     Gears  \
# 0    1.0   0.278481  0.193355  0.170732  0.047619  0.333333  0.666667
# 1    1.0   0.278481  0.300149  0.170732  0.047619  0.333333  0.666667
# 2    1.0   0.291139  0.171647  0.170732  0.047619  0.333333  0.666667
# 3    1.0   0.316456  0.197528  0.170732  0.047619  0.333333  0.666667
# 4    1.0   0.367089  0.158433  0.170732  0.047619  0.333333  0.666667
#
#    Quarterly_Tax    Weight
# 0       0.723485  0.268293
# 1       0.723485  0.268293
# 2       0.723485  0.268293
# 3       0.723485  0.268293
# 4       0.723485  0.276423

# %%
model2 = sm.OLS(y,x2).fit()
x_const2 = sm.add_constant(x2)
y_pred2 = model2.predict(x_const2)
r2_minmax = r2_score(y,y_pred2)
r2_minmax
# Out:
# 0.8637627463428192

# %% [markdown]
# ###### It seems there is no significant change in the result after applying MinMax scaling.

# %%
x.head()
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0         23  46986  90  2000      3      5            210    1165
# 1         23  72937  90  2000      3      5            210    1165
# 2         24  41711  90  2000      3      5            210    1165
# 3         26  48000  90  2000      3      5            210    1165
# 4         30  38500  90  2000      3      5            210    1170

# %% [markdown]
# #### Using Square root transformation

# %%
x3 = x.copy()
x3["Age_08_04"] = np.sqrt(x3["Age_08_04"])
x3["KM"] = np.sqrt(x3["KM"])
x3["HP"] = np.sqrt(x3["HP"])
x3["cc"] = np.sqrt(x3["cc"])
x3["Doors"] = np.sqrt(x3["Doors"])
x3["Gears"] = np.sqrt(x3["Gears"])
x3["Quarterly_Tax"] = np.sqrt(x3["Quarterly_Tax"])
x3["Weight"] = np.sqrt(x3["Weight"])
x3.head()
# Out:
#    Age_08_04          KM        HP        cc     Doors     Gears  \
# 0   4.795832  216.762543  9.486833  44.72136  1.732051  2.236068
# 1   4.795832  270.068510  9.486833  44.72136  1.732051  2.236068
# 2   4.898979  204.232710  9.486833  44.72136  1.732051  2.236068
# 3   5.099020  219.089023  9.486833  44.72136  1.732051  2.236068
# 4   5.477226  196.214169  9.486833  44.72136  1.732051  2.236068
#
#    Quarterly_Tax     Weight
# 0      14.491377  34.132096
# 1      14.491377  34.132096
# 2      14.491377  34.132096
# 3      14.491377  34.132096
# 4      14.491377  34.205263

# %%
model3 = sm.OLS(y,x3).fit()
x_const3 = sm.add_constant(x3)
y_pred3 = model3.predict(x3)
r2_sqrt = r2_score(y,y_pred3)
r2_sqrt
# Out:
# 0.8716765524268697

# %% [markdown]
# #### Log Transformation

# %%
x4 = x.copy()
x4["Age_08_04"] = np.log(x4["Age_08_04"])
x4["KM"] = np.log(x4["KM"])
x4["HP"] = np.log(x4["HP"])
x4["cc"] = np.log(x4["cc"])
x4["Doors"] = np.log(x4["Doors"])
x4["Gears"] = np.log(x4["Gears"])
x4["Quarterly_Tax"] = np.log(x4["Quarterly_Tax"])
x4["Weight"] = np.log(x4["Weight"])
x4.head()
# Out:
#    Age_08_04         KM       HP        cc     Doors     Gears  Quarterly_Tax  \
# 0   3.135494  10.757605  4.49981  7.600902  1.098612  1.609438       5.347108
# 1   3.135494  11.197351  4.49981  7.600902  1.098612  1.609438       5.347108
# 2   3.178054  10.638520  4.49981  7.600902  1.098612  1.609438       5.347108
# 3   3.258097  10.778956  4.49981  7.600902  1.098612  1.609438       5.347108
# 4   3.401197  10.558414  4.49981  7.600902  1.098612  1.609438       5.347108
#
#      Weight
# 0  7.060476
# 1  7.060476
# 2  7.060476
# 3  7.060476
# 4  7.064759

# %%
model4 = sm.OLS(y,x4).fit()
x_const4 = sm.add_constant(x4)
y_pred4 = model4.predict(x4)
r2_log = r2_score(y,y_pred4)
r2_log
# Out:
# 0.817174713415513

# %% [markdown]
# #### Using Ridge and Lasso regressors

# %%
ridg = Ridge(alpha = 0.8)
ridg.fit(x,y)
y_pred5 = ridg.predict(x)
r_2_ridg = r2_score(y,y_pred5)
r_2_ridg
# Out:
# 0.8637624971753441

# %%
lass = Lasso(alpha = 0.8)
lass.fit(x,y)
y_pred6 = lass.predict(x)
r_2_lass = r2_score(y,y_pred6)
r_2_lass
# Out:
# 0.863761304444923

# %%
data = [["No transformation", r2], ["MinMax Scaler", r2_minmax], ["Square root transformation", r2_sqrt], 
        ["Logarithmic transformation", r2_log], ["Ridge Regressor", r_2_ridg], ["Lasso Regressor", r_2_lass]]
r2Table = pd.DataFrame(data, columns = ["Transformation", "R-2 score"])
r2Table
# Out:
#                Transformation  R-2 score
# 0           No transformation   0.863763
# 1               MinMax Scaler   0.863763
# 2  Square root transformation   0.871677
# 3  Logarithmic transformation   0.817175
# 4             Ridge Regressor   0.863762
# 5             Lasso Regressor   0.863761
